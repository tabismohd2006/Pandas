# %% [markdown]
# <a href="https://colab.research.google.com/github/tabismohd2006/Pandas/blob/main/Histogram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Module 4 Histogram

# %% [markdown]
# Dataset

# %%
import pandas as pd
import matplotlib.pylot as plt
df = pd.read_csv("/content/house_price.csv", on_bad_lines='skip', engine='python')
print("DataFrame Columns:", df.columns)
plt.figure(figsize=(10,5))
plt.hits(df["price (in rupe)"])
plt.title("Basic Histrogram")
plt.show()

# %% [markdown]
# bins

# %%
import pandas as pd
import matplotlib.pylot as plt
df = pd.read_csv("/content/house_price.csv", on_bad_lines='skip', engine='python')
print("DataFrame Columns:", df.columns)
plt.figure(figsize=(10,5))
plt.hits(df["price (in rupe)"])
plt.title("Basic Histrogram")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# CSV file read
df = pd.read_csv("house_data.csv")

# House Price Distribution
plt.figure(figsize=(8,5))
plt.hist(df["Price"], bins=5, color="skyblue", edgecolor="black")

plt.title("House Price Distribution")
plt.xlabel("House Price")
plt.ylabel("Frequency")

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("  Iris.csv")
plt.figure(figsize=(8,5))
plt.scatter(
    df["SepalLengthCm"],
    df["SepalWidthCm"],

)

# %%
import pandas as pd

# TXT file read
df = pd.read_csv("/content/house.txt")

# CSV file save
df.to_csv("house_data.csv", index=False)

print("TXT file successfully converted to CSV.")
# Out:
# TXT file successfully converted to CSV.

# %% [markdown]
# pie chart

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("/content/house_price.csv", on_bad_lines='skip', engine='python')
print("DataFrame Columns:", df.columns)

# %% [markdown]
# Box Plot

# %%
import pandas as pd
import mataplotlib.pyplot as plt
df = pd.read_csv("/content/house_price.csv", on_bad_lines='skip', engine='python')
print("DataFrame Columns:", df.columns)
